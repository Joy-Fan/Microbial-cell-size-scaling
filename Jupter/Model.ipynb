# %%
#Packages
install.packages("ggplot2")
install.packages("dplyr")
library(ggplot2)
library(dplyr)

# Clear the data
rm(list=ls())

#Import the Data
Data <- read.csv("C:/Users/FAN/Desktop/Data/Tables/Data_new.csv", as.is=TRUE)

#Arrhenius
k <- 8.62e-5 
Data$arrhenius_tmp<-1/(k*Data$Temp)

# %%
#Model fitting
list_of_Phylum = split(Data,Data$ConPhylum)
results = lapply(list_of_Phylum, function(Data) lm(log(GrowthRate)~log(AverageVolume)+arrhenius_tmp, data = Data))
lapply(results,summary)
# Out:
# $Actinobacteria
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4.1091 -0.7980  0.2663  1.1815  1.9630
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)        -8.86047   22.80030  -0.389    0.707
# log(AverageVolume) -0.06616    0.42877  -0.154    0.881
# arrhenius_tmp      -0.13391    0.42316  -0.316    0.759
#
# Residual standard error: 1.889 on 9 degrees of freedom
# Multiple R-squared:  0.0128,	Adjusted R-squared:  -0.2066
# F-statistic: 0.05837 on 2 and 9 DF,  p-value: 0.9437
#
#
# $Aquificae
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.4230 -0.8947 -0.4512  1.1624  2.1972
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)           7.466     99.736   0.075    0.942
# log(AverageVolume)    1.172      1.695   0.691    0.512
# arrhenius_tmp         0.915      1.728   0.530    0.613
#
# Residual standard error: 1.689 on 7 degrees of freedom
# Multiple R-squared:  0.1132,	Adjusted R-squared:  -0.1402
# F-statistic: 0.4466 on 2 and 7 DF,  p-value: 0.6568
#
#
# $Bacillariophyta
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.87822 -0.13411  0.04899  0.24116  1.00969
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)         2.73514    3.32937   0.822    0.416
# log(AverageVolume) -0.02460    0.03203  -0.768    0.447
# arrhenius_tmp      -0.37308    0.07258  -5.140 6.06e-06 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.5565 on 44 degrees of freedom
# Multiple R-squared:  0.414,	Adjusted R-squared:  0.3873
# F-statistic: 15.54 on 2 and 44 DF,  p-value: 7.844e-06
#
#
# $Bacteroidetes
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Data)
#
# Residuals:
#      57     272     273     274     275     276     277
# -0.6030 -1.9011  1.2106  0.9830  2.0995 -1.8477  0.0588
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)         -6.9698    23.1016  -0.302    0.778
# log(AverageVolume)   0.2921     0.5392   0.542    0.617
# arrhenius_tmp        0.1881     0.3554   0.529    0.625
#
# Residual standard error: 1.886 on 4 degrees of freedom
# Multiple R-squared:  0.1016,	Adjusted R-squared:  -0.3476
# F-statistic: 0.2262 on 2 and 4 DF,  p-value: 0.8071
#
#
# $Balneolaeota
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Data)
#
# Residuals:
# ALL 2 residuals are 0: no residual degrees of freedom!
#
# Coefficients: (1 not defined because of singularities)
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)         -4.0377         NA      NA       NA
# log(AverageVolume)   0.1445         NA      NA       NA
# arrhenius_tmp            NA         NA      NA       NA
#
# Residual standard error: NaN on 0 degrees of freedom
# Multiple R-squared:      1,	Adjusted R-squared:    NaN
# F-statistic:   NaN on 1 and 0 DF,  p-value: NA
#
#
# $Chloroflexi
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Data)
#
# Residuals:
#      58      59     280     281     282
#  0.8386 -1.0697 -0.1649  0.2455  0.1505
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)        -17.2634    15.7729  -1.094    0.388
# log(AverageVolume)  -0.3895     0.3368  -1.156    0.367
# arrhenius_tmp       -0.3154     0.5956  -0.530    0.649
#
# Residual standard error: 0.9894 on 2 degrees of freedom
# Multiple R-squared:  0.4274,	Adjusted R-squared:  -0.1452
# F-statistic: 0.7465 on 2 and 2 DF,  p-value: 0.5726
#
#
# $Chlorophyta
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.2083 -1.8843 -0.0734  1.5613  6.0025
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)        -15.6897    38.0639  -0.412  0.68691
# log(AverageVolume)   1.2571     0.3756   3.347  0.00526 **
# arrhenius_tmp        1.2765     0.7542   1.693  0.11434
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 3.311 on 13 degrees of freedom
# Multiple R-squared:  0.6805,	Adjusted R-squared:  0.6314
# F-statistic: 13.85 on 2 and 13 DF,  p-value: 0.000601
#
#
# $Crenarchaeota
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Data)
#
# Residuals:
#      75     284     285     286     287     288     289
#  0.6288 -0.5748 -0.7115 -0.8079 -0.6323  3.5921 -1.4945
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)        -23.9400    62.8205  -0.381    0.723
# log(AverageVolume)  -0.1700     0.5171  -0.329    0.759
# arrhenius_tmp        0.1147     2.2031   0.052    0.961
#
# Residual standard error: 2.087 on 4 degrees of freedom
# Multiple R-squared:  0.04432,	Adjusted R-squared:  -0.4335
# F-statistic: 0.09276 on 2 and 4 DF,  p-value: 0.9133
#
#
# $Cyanobacteria
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.0911 -0.5001  0.3002  0.3305  0.8581
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)        -8.05330   11.28386  -0.714    0.492
# log(AverageVolume)  0.01579    0.07009   0.225    0.826
# arrhenius_tmp      -0.08466    0.28363  -0.298    0.771
#
# Residual standard error: 0.6255 on 10 degrees of freedom
# Multiple R-squared:  0.01366,	Adjusted R-squared:  -0.1836
# F-statistic: 0.06926 on 2 and 10 DF,  p-value: 0.9335
#
#
# $Cyanophyta
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.18362 -0.51079 -0.04646  0.60367  1.04549
#
# Coefficients:
#                     Estimate Std. Error t value Pr(>|t|)
# (Intercept)        -21.32968   14.03258  -1.520   0.1628
# log(AverageVolume)  -0.25316    0.11062  -2.289   0.0479 *
# arrhenius_tmp        0.01299    0.30145   0.043   0.9666
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.8077 on 9 degrees of freedom
# Multiple R-squared:  0.456,	Adjusted R-squared:  0.3351
# F-statistic: 3.772 on 2 and 9 DF,  p-value: 0.06459
#
#
# $Deferribacteres
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Data)
#
# Residuals:
# ALL 2 residuals are 0: no residual degrees of freedom!
#
# Coefficients: (1 not defined because of singularities)
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)        -138.721         NA      NA       NA
# log(AverageVolume)   -3.088         NA      NA       NA
# arrhenius_tmp            NA         NA      NA       NA
#
# Residual standard error: NaN on 0 degrees of freedom
# Multiple R-squared:      1,	Adjusted R-squared:    NaN
# F-statistic:   NaN on 1 and 0 DF,  p-value: NA
#
#
# $`Deinococcus-Thermus`
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Data)
#
# Residuals:
#      80      81      82      83      84      85     313
#  0.8016  0.7074  0.4054 -1.6172 -0.7721  1.3720 -0.8971
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)         72.4244    39.3580   1.840    0.140
# log(AverageVolume)   1.2907     0.6089   2.120    0.101
# arrhenius_tmp       -0.8221     0.5070  -1.621    0.180
#
# Residual standard error: 1.342 on 4 degrees of freedom
# Multiple R-squared:  0.5317,	Adjusted R-squared:  0.2976
# F-statistic: 2.271 on 2 and 4 DF,  p-value: 0.2193
#
#
# $Euryarchaeota
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.3918 -1.0444 -0.1602  0.8768  3.6201
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)         5.38767    5.39098   0.999  0.31930
# log(AverageVolume)  0.30280    0.11391   2.658  0.00875 **
# arrhenius_tmp      -0.13200    0.06736  -1.959  0.05200 .
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 1.675 on 143 degrees of freedom
# Multiple R-squared:  0.06766,	Adjusted R-squared:  0.05462
# F-statistic: 5.189 on 2 and 143 DF,  p-value: 0.006677
#
#
# $Firmicutes
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4.2868 -1.1607 -0.0133  1.1310  4.3556
#
# Coefficients:
#                     Estimate Std. Error t value Pr(>|t|)
# (Intercept)        -18.19537    7.10481  -2.561  0.01154 *
# log(AverageVolume)   0.14915    0.13621   1.095  0.27545
# arrhenius_tmp        0.37908    0.09623   3.940  0.00013 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 1.792 on 135 degrees of freedom
# Multiple R-squared:  0.1222,	Adjusted R-squared:  0.1092
# F-statistic:   9.4 on 2 and 135 DF,  p-value: 0.0001507
#
#
# $Haptophyta
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Data)
#
# Residuals:
#      168      169      170      171      172
# -0.43064  0.23902 -0.14628  0.36460 -0.02671
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)        -16.7057    34.1328  -0.489    0.673
# log(AverageVolume)  -0.4146     0.2238  -1.853    0.205
# arrhenius_tmp       -0.2530     0.7251  -0.349    0.760
#
# Residual standard error: 0.4459 on 2 degrees of freedom
# Multiple R-squared:  0.7714,	Adjusted R-squared:  0.5429
# F-statistic: 3.375 on 2 and 2 DF,  p-value: 0.2286
#
#
# $Ochrophyta
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Data)
#
# Residuals:
#     173     174     175     176     177
#  0.3839 -0.2300 -0.1597  0.2318 -0.2260
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)        10.71537   11.75197   0.912   0.4581
# log(AverageVolume) -0.17505    0.09974  -1.755   0.2213
# arrhenius_tmp      -0.73299    0.23590  -3.107   0.0898 .
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.4066 on 2 degrees of freedom
# Multiple R-squared:  0.9385,	Adjusted R-squared:  0.877
# F-statistic: 15.26 on 2 and 2 DF,  p-value: 0.06152
#
#
# $Others
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.65264 -0.42313 -0.09618  0.52919  1.00871
#
# Coefficients:
#                     Estimate Std. Error t value Pr(>|t|)
# (Intercept)        -18.66102    5.01643  -3.720  0.00119 **
# log(AverageVolume)  -0.01575    0.05242  -0.300  0.76670
# arrhenius_tmp        0.14528    0.10061   1.444  0.16281
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.5391 on 22 degrees of freedom
# Multiple R-squared:  0.09797,	Adjusted R-squared:  0.01596
# F-statistic: 1.195 on 2 and 22 DF,  p-value: 0.3217
#
#
# $Planctomycetes
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Data)
#
# Residuals:
# ALL 2 residuals are 0: no residual degrees of freedom!
#
# Coefficients: (1 not defined because of singularities)
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)         -51.943         NA      NA       NA
# log(AverageVolume)   -1.038         NA      NA       NA
# arrhenius_tmp            NA         NA      NA       NA
#
# Residual standard error: NaN on 0 degrees of freedom
# Multiple R-squared:      1,	Adjusted R-squared:    NaN
# F-statistic:   NaN on 1 and 0 DF,  p-value: NA
#
#
# $Proteobacteria
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4.9209 -0.9096  0.1381  1.0439  3.6961
#
# Coefficients:
#                     Estimate Std. Error t value Pr(>|t|)
# (Intercept)        -14.12239    7.75399  -1.821   0.0713 .
# log(AverageVolume)  -0.07014    0.12878  -0.545   0.5871
# arrhenius_tmp        0.01923    0.09907   0.194   0.8464
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 1.596 on 108 degrees of freedom
# Multiple R-squared:  0.00275,	Adjusted R-squared:  -0.01572
# F-statistic: 0.1489 on 2 and 108 DF,  p-value: 0.8618
#
#
# $Spirochaetes
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Data)
#
# Residuals:
#     220     612     613     614     615
# -0.4995 -0.5171 -0.1153  1.2739 -0.1420
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)         12.9092    27.7933   0.464    0.688
# log(AverageVolume)   0.3765     0.3810   0.988    0.427
# arrhenius_tmp       -0.2429     0.4865  -0.499    0.667
#
# Residual standard error: 1.042 on 2 degrees of freedom
# Multiple R-squared:  0.3359,	Adjusted R-squared:  -0.3283
# F-statistic: 0.5057 on 2 and 2 DF,  p-value: 0.6641
#
#
# $Streptophyta
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.66546 -0.15886  0.03654  0.18030  0.36860
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)         3.15324    6.87868   0.458  0.65323
# log(AverageVolume) -0.19586    0.04501  -4.351  0.00057 ***
# arrhenius_tmp      -0.55826    0.16279  -3.429  0.00373 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.3051 on 15 degrees of freedom
# Multiple R-squared:  0.7396,	Adjusted R-squared:  0.7049
# F-statistic: 21.31 on 2 and 15 DF,  p-value: 4.138e-05
#
#
# $Synergistetes
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Data)
#
# Residuals:
# ALL 3 residuals are 0: no residual degrees of freedom!
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)         1001.06         NA      NA       NA
# log(AverageVolume)    15.24         NA      NA       NA
# arrhenius_tmp        -10.92         NA      NA       NA
#
# Residual standard error: NaN on 0 degrees of freedom
# Multiple R-squared:      1,	Adjusted R-squared:    NaN
# F-statistic:   NaN on 2 and 0 DF,  p-value: NA
#
#
# $Thermodesulfobacteria
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Data)
#
# Residuals:
#       242       243       244       245
# -0.002044 -0.003209 -0.009796  0.015050
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)        45.36026    1.56986   28.89   0.0220 *
# log(AverageVolume)  0.12254    0.01010   12.14   0.0523 .
# arrhenius_tmp      -1.56030    0.04155  -37.56   0.0169 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.01836 on 1 degrees of freedom
# Multiple R-squared:  0.9993,	Adjusted R-squared:  0.9979
# F-statistic: 709.2 on 2 and 1 DF,  p-value: 0.02654
#
#
# $Thermotogae
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.77600 -0.61083 -0.06833  0.39422  2.90757
#
# Coefficients:
#                     Estimate Std. Error t value Pr(>|t|)
# (Intercept)        78.311317  31.103554   2.518   0.0305 *
# log(AverageVolume) -0.005569   0.261685  -0.021   0.9834
# arrhenius_tmp      -2.594323   1.031843  -2.514   0.0307 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 1.498 on 10 degrees of freedom
# Multiple R-squared:  0.4753,	Adjusted R-squared:  0.3704
# F-statistic: 4.529 on 2 and 10 DF,  p-value: 0.03977

# %%
#Coef
read.csv("C:/Users/FAN/Desktop/Results/Tables/Coef1.csv", as.is=TRUE)
# Out:
#    ConPhylum             Kingdom       N   r.sqr       lntercept   Pr
# 1  Crenarchaeota         Archaea         7 0.044324132  -23.939959 0.72300
# 2  Euryarchaeota         Archaea       146 0.067658689    5.387670 0.31930
# 3  Actinobacteria        Bacteria       12 0.012804253   -8.860466 0.70700
# 4  Aquificae             Bacteria       10 0.113155852    7.466141 0.94200
# 5  Bacteroidetes         Bacteria        7 0.101627225   -6.969800 0.77800
# 6  Chloroflexi           Bacteria        5 0.427423425  -17.263402 0.38800
# 7  Cyanobacteria         Bacteria       13 0.013662209   -8.053303 0.49200
# 8  Cyanophyta            Bacteria       12 0.456007727  -21.329676 0.16280
# 9  Deferribacteres       Bacteria        2 1.000000000 -138.720542      NA
# 10 Deinococcus-Thermus   Bacteria        7 0.531709318   72.424406 0.14000
# 11 Firmicutes            Bacteria      138 0.122233681  -18.195369 0.01154
# 12 Planctomycetes        Bacteria        2 1.000000000  -51.943088      NA
# 13 Proteobacteria        Bacteria      111 0.002750267  -14.122393 0.07130
# 14 Spirochaetes          Bacteria        5 0.335865826   12.909168 0.68800
# 15 Synergistetes         Bacteria        3 1.000000000 1001.063134      NA
# 16 Thermodesulfobacteria Bacteria        4 0.999295477   45.360263 0.02200
# 17 Thermotogae           Bacteria       13 0.475311597   78.311317 0.03050
# 18 Bacillariophyta       Phytoplankton  47 0.413951051    2.735143 0.41600
# 19 Balneolaeota          Phytoplankton   2 1.000000000   -4.037676      NA
# 20 Chlorophyta           Phytoplankton  16 0.680522347  -15.689717 0.68691
# 21 Haptophyta            Phytoplankton   5 0.771446798  -16.705661 0.67300
# 22 Ochrophyta            Phytoplankton   5 0.938484170   10.715373 0.45810
# 23 Others                Phytoplankton  25 0.097966050  -18.661024 0.00119
# 24 Streptophyta          Phytoplankton  18 0.739639836    3.153237 0.65323
#    a            Pr.1    RE           Pr.2       p.value
# 1  -0.169969539 0.75900   0.11466337 0.96100000 9.133e-01
# 2   0.302802699 0.00875  -0.13199906 0.05200000 6.677e-03
# 3  -0.066157598 0.88100  -0.13390869 0.75900000 9.437e-01
# 4   1.171984262 0.51200   0.91502483 0.61300000 6.568e-01
# 5   0.292119213 0.61700   0.18808614 0.62500000 8.071e-01
# 6  -0.389466106 0.36700  -0.31539859 0.64900000 5.726e-01
# 7   0.015789323 0.82600  -0.08466199 0.77100000 9.335e-01
# 8  -0.253158148 0.04790   0.01298742 0.96660000 6.459e-02
# 9  -3.088376214      NA           NA         NA        NA
# 10  1.290710782 0.10100  -0.82209392 0.18000000 2.193e-01
# 11  0.149153504 0.27545   0.37908445 0.00013000 1.507e-04
# 12 -1.038299533      NA           NA         NA        NA
# 13 -0.070139816 0.58710   0.01923253 0.84640000 8.618e-01
# 14  0.376469537 0.42700  -0.24286376 0.66700000 6.641e-01
# 15 15.239073630      NA -10.91917394         NA        NA
# 16  0.122538999 0.05230  -1.56029732 0.01690000 2.654e-02
# 17 -0.005568896 0.98340  -2.59432275 0.03070000 3.977e-02
# 18 -0.024598921 0.44700  -0.37307741 0.00000606 7.840e-06
# 19  0.144506836      NA           NA         NA        NA
# 20  1.257117026 0.00526   1.27649815 0.11434000 6.010e-04
# 21 -0.414598939 0.20500  -0.25302756 0.76000000 2.286e-01
# 22 -0.175050615 0.22130  -0.73299129 0.08980000 6.152e-02
# 23 -0.015745821 0.76670   0.14528319 0.16281000 3.217e-01
# 24 -0.195855561 0.00057  -0.55826394 0.00373000 4.140e-05

# %%
##classified based on breakpoint(40c)
Meso<-subset(Data,TempPref=="Mesophile")
Thermo<-subset(Data,TempPref=="Thermophile")

#Model fitting for Meso
list_of_Phylum = split(Meso,Meso$ConPhylum)
results1 = lapply(list_of_Phylum, function(Meso) lm(log(GrowthRate)~log(AverageVolume)+arrhenius_tmp, data = Meso))
lapply(results1,summary)
                  
list_of_Phylum = split(Thermo,Thermo$ConPhylum)
results2 = lapply(list_of_Phylum, function(Thermo) lm(log(GrowthRate)~log(AverageVolume)+arrhenius_tmp, data = Thermo))
lapply(results2,summary)
# Out:
# $Actinobacteria
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Meso)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.9324 -0.3572 -0.2327  1.5671  2.2293
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)        -26.5993    60.7483  -0.438    0.677
# log(AverageVolume)  -0.1268     0.5230  -0.242    0.817
# arrhenius_tmp        0.2661     1.3615   0.195    0.851
#
# Residual standard error: 2.193 on 6 degrees of freedom
# Multiple R-squared:  0.01289,	Adjusted R-squared:  -0.3161
# F-statistic: 0.03919 on 2 and 6 DF,  p-value: 0.9618
#
#
# $Bacillariophyta
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Meso)
#
# Residuals:
#        268        269        270        271
# -4.397e-01  4.029e-01  3.677e-02 -2.745e-14
#
# Coefficients:
#                     Estimate Std. Error t value Pr(>|t|)
# (Intercept)         16.30678  263.96039   0.062    0.961
# log(AverageVolume)  -0.06637    0.18221  -0.364    0.778
# arrhenius_tmp       -0.73180    6.40046  -0.114    0.928
#
# Residual standard error: 0.5975 on 1 degrees of freedom
# Multiple R-squared:  0.1471,	Adjusted R-squared:  -1.559
# F-statistic: 0.0862 on 2 and 1 DF,  p-value: 0.9236
#
#
# $Bacteroidetes
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Meso)
#
# Residuals:
#      272      273      274      275      276      277
# -1.67390  0.03401 -0.08493  1.80959 -1.34996  1.26519
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)         45.6625    48.2968   0.945    0.414
# log(AverageVolume)   0.3690     0.5127   0.720    0.524
# arrhenius_tmp       -1.0545     1.0713  -0.984    0.398
#
# Residual standard error: 1.78 on 3 degrees of freedom
# Multiple R-squared:  0.3245,	Adjusted R-squared:  -0.1259
# F-statistic: 0.7205 on 2 and 3 DF,  p-value: 0.5552
#
#
# $Balneolaeota
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Meso)
#
# Residuals:
# ALL 2 residuals are 0: no residual degrees of freedom!
#
# Coefficients: (1 not defined because of singularities)
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)         -4.0377         NA      NA       NA
# log(AverageVolume)   0.1445         NA      NA       NA
# arrhenius_tmp            NA         NA      NA       NA
#
# Residual standard error: NaN on 0 degrees of freedom
# Multiple R-squared:      1,	Adjusted R-squared:    NaN
# F-statistic:   NaN on 1 and 0 DF,  p-value: NA
#
#
# $Chloroflexi
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Meso)
#
# Residuals:
# ALL 3 residuals are 0: no residual degrees of freedom!
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)        -65.6802         NA      NA       NA
# log(AverageVolume)  -0.1363         NA      NA       NA
# arrhenius_tmp        1.2454         NA      NA       NA
#
# Residual standard error: NaN on 0 degrees of freedom
# Multiple R-squared:      1,	Adjusted R-squared:    NaN
# F-statistic:   NaN on 2 and 0 DF,  p-value: NA
#
#
# $Chlorophyta
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Meso)
#
# Residuals:
# ALL 1 residuals are 0: no residual degrees of freedom!
#
# Coefficients: (2 not defined because of singularities)
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)           10.21         NA      NA       NA
# log(AverageVolume)       NA         NA      NA       NA
# arrhenius_tmp            NA         NA      NA       NA
#
# Residual standard error: NaN on 0 degrees of freedom
#
#
# $Crenarchaeota
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Meso)
#
# Residuals:
#     284     285     286     287     288     289
# -0.4593 -0.1663 -1.1161 -0.4407  3.5929 -1.4105
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)        -42.6828    85.4687  -0.499    0.652
# log(AverageVolume)  -0.2590     0.6253  -0.414    0.707
# arrhenius_tmp        0.5741     2.7457   0.209    0.848
#
# Residual standard error: 2.351 on 3 degrees of freedom
# Multiple R-squared:  0.08985,	Adjusted R-squared:  -0.5169
# F-statistic: 0.1481 on 2 and 3 DF,  p-value: 0.8683
#
#
# $Cyanobacteria
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Meso)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -1.0911 -0.5001  0.3002  0.3305  0.8581
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)        -8.05330   11.28386  -0.714    0.492
# log(AverageVolume)  0.01579    0.07009   0.225    0.826
# arrhenius_tmp      -0.08466    0.28363  -0.298    0.771
#
# Residual standard error: 0.6255 on 10 degrees of freedom
# Multiple R-squared:  0.01366,	Adjusted R-squared:  -0.1836
# F-statistic: 0.06926 on 2 and 10 DF,  p-value: 0.9335
#
#
# $Cyanophyta
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Meso)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.20737 -0.55117  0.01371  0.71309  0.87471
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)        -28.3004    22.6187  -1.251    0.251
# log(AverageVolume)  -0.2324     0.1278  -1.818    0.112
# arrhenius_tmp        0.2154     0.5823   0.370    0.722
#
# Residual standard error: 0.8702 on 7 degrees of freedom
# Multiple R-squared:  0.3301,	Adjusted R-squared:  0.1387
# F-statistic: 1.725 on 2 and 7 DF,  p-value: 0.246
#
#
# $`Deinococcus-Thermus`
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Meso)
#
# Residuals:
# ALL 1 residuals are 0: no residual degrees of freedom!
#
# Coefficients: (2 not defined because of singularities)
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)          -10.33         NA      NA       NA
# log(AverageVolume)       NA         NA      NA       NA
# arrhenius_tmp            NA         NA      NA       NA
#
# Residual standard error: NaN on 0 degrees of freedom
#
#
# $Euryarchaeota
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Meso)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -3.2913 -0.9828 -0.1887  0.7111  3.7337
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)         0.91825    5.42173   0.169   0.8658
# log(AverageVolume)  0.24157    0.11309   2.136   0.0345 *
# arrhenius_tmp      -0.07924    0.07524  -1.053   0.2942
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 1.614 on 136 degrees of freedom
# Multiple R-squared:  0.03966,	Adjusted R-squared:  0.02554
# F-statistic: 2.808 on 2 and 136 DF,  p-value: 0.0638
#
#
# $Firmicutes
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Meso)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -4.3081 -0.8622  0.0826  0.9120  2.5048
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)        -22.3855    12.8620  -1.740   0.0869 .
# log(AverageVolume)  -0.2292     0.1506  -1.522   0.1332
# arrhenius_tmp        0.0779     0.2896   0.269   0.7889
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 1.424 on 60 degrees of freedom
# Multiple R-squared:  0.03773,	Adjusted R-squared:  0.005656
# F-statistic: 1.176 on 2 and 60 DF,  p-value: 0.3154
#
#
# $Others
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Meso)
#
# Residuals:
# ALL 1 residuals are 0: no residual degrees of freedom!
#
# Coefficients: (2 not defined because of singularities)
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)          -12.48         NA      NA       NA
# log(AverageVolume)       NA         NA      NA       NA
# arrhenius_tmp            NA         NA      NA       NA
#
# Residual standard error: NaN on 0 degrees of freedom
#
#
# $Planctomycetes
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Meso)
#
# Residuals:
# ALL 1 residuals are 0: no residual degrees of freedom!
#
# Coefficients: (2 not defined because of singularities)
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)          -11.21         NA      NA       NA
# log(AverageVolume)       NA         NA      NA       NA
# arrhenius_tmp            NA         NA      NA       NA
#
# Residual standard error: NaN on 0 degrees of freedom
#
#
# $Proteobacteria
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Meso)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -5.1373 -0.9895  0.1072  1.0763  3.3619
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)        -9.12796    9.33929  -0.977    0.331
# log(AverageVolume) -0.09559    0.14132  -0.676    0.501
# arrhenius_tmp      -0.13414    0.14299  -0.938    0.351
#
# Residual standard error: 1.632 on 91 degrees of freedom
# Multiple R-squared:  0.02141,	Adjusted R-squared:  -9.403e-05
# F-statistic: 0.9956 on 2 and 91 DF,  p-value: 0.3735
#
#
# $Spirochaetes
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Meso)
#
# Residuals:
#      612      613      614      615
# -0.46727  0.36428  0.12962 -0.02663
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)         79.5032    34.1719   2.327    0.258
# log(AverageVolume)   0.7205     0.2709   2.659    0.229
# arrhenius_tmp       -1.6146     0.6816  -2.369    0.254
#
# Residual standard error: 0.6071 on 1 degrees of freedom
# Multiple R-squared:  0.8871,	Adjusted R-squared:  0.6613
# F-statistic: 3.928 on 2 and 1 DF,  p-value: 0.336
# $Actinobacteria
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Thermo)
#
# Residuals:
# ALL 3 residuals are 0: no residual degrees of freedom!
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)         5588.57         NA      NA       NA
# log(AverageVolume)   113.51         NA      NA       NA
# arrhenius_tmp        -26.45         NA      NA       NA
#
# Residual standard error: NaN on 0 degrees of freedom
# Multiple R-squared:      1,	Adjusted R-squared:    NaN
# F-statistic:   NaN on 2 and 0 DF,  p-value: NA
#
#
# $Aquificae
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Thermo)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.4230 -0.8947 -0.4512  1.1624  2.1972
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)           7.466     99.736   0.075    0.942
# log(AverageVolume)    1.172      1.695   0.691    0.512
# arrhenius_tmp         0.915      1.728   0.530    0.613
#
# Residual standard error: 1.689 on 7 degrees of freedom
# Multiple R-squared:  0.1132,	Adjusted R-squared:  -0.1402
# F-statistic: 0.4466 on 2 and 7 DF,  p-value: 0.6568
#
#
# $Bacillariophyta
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Thermo)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.89471 -0.14606  0.03588  0.25000  0.99785
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)         2.15898    4.08801   0.528 0.600330
# log(AverageVolume) -0.02293    0.03444  -0.666 0.509391
# arrhenius_tmp      -0.35689    0.09157  -3.898 0.000362 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.5746 on 40 degrees of freedom
# Multiple R-squared:  0.3142,	Adjusted R-squared:  0.2799
# F-statistic: 9.163 on 2 and 40 DF,  p-value: 0.0005297
#
#
# $Bacteroidetes
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Thermo)
#
# Residuals:
# ALL 1 residuals are 0: no residual degrees of freedom!
#
# Coefficients: (2 not defined because of singularities)
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)          -13.12         NA      NA       NA
# log(AverageVolume)       NA         NA      NA       NA
# arrhenius_tmp            NA         NA      NA       NA
#
# Residual standard error: NaN on 0 degrees of freedom
#
#
# $Chloroflexi
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Thermo)
#
# Residuals:
# ALL 2 residuals are 0: no residual degrees of freedom!
#
# Coefficients: (1 not defined because of singularities)
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)         160.306         NA      NA       NA
# log(AverageVolume)    4.494         NA      NA       NA
# arrhenius_tmp            NA         NA      NA       NA
#
# Residual standard error: NaN on 0 degrees of freedom
# Multiple R-squared:      1,	Adjusted R-squared:    NaN
# F-statistic:   NaN on 1 and 0 DF,  p-value: NA
#
#
# $Chlorophyta
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Thermo)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.41034 -0.16820  0.08945  0.30917  0.83754
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)        -7.45268    6.61510  -1.127    0.282
# log(AverageVolume) -0.08612    0.09242  -0.932    0.370
# arrhenius_tmp      -0.18351    0.14896  -1.232    0.242
#
# Residual standard error: 0.5744 on 12 degrees of freedom
# Multiple R-squared:  0.1641,	Adjusted R-squared:  0.02477
# F-statistic: 1.178 on 2 and 12 DF,  p-value: 0.3412
#
#
# $Crenarchaeota
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Thermo)
#
# Residuals:
# ALL 1 residuals are 0: no residual degrees of freedom!
#
# Coefficients: (2 not defined because of singularities)
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)          -13.25         NA      NA       NA
# log(AverageVolume)       NA         NA      NA       NA
# arrhenius_tmp            NA         NA      NA       NA
#
# Residual standard error: NaN on 0 degrees of freedom
#
#
# $Cyanophyta
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Thermo)
#
# Residuals:
# ALL 2 residuals are 0: no residual degrees of freedom!
#
# Coefficients: (1 not defined because of singularities)
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)        -35.5381         NA      NA       NA
# log(AverageVolume)  -0.6231         NA      NA       NA
# arrhenius_tmp            NA         NA      NA       NA
#
# Residual standard error: NaN on 0 degrees of freedom
# Multiple R-squared:      1,	Adjusted R-squared:    NaN
# F-statistic:   NaN on 1 and 0 DF,  p-value: NA
#
#
# $Deferribacteres
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Thermo)
#
# Residuals:
# ALL 2 residuals are 0: no residual degrees of freedom!
#
# Coefficients: (1 not defined because of singularities)
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)        -138.721         NA      NA       NA
# log(AverageVolume)   -3.088         NA      NA       NA
# arrhenius_tmp            NA         NA      NA       NA
#
# Residual standard error: NaN on 0 degrees of freedom
# Multiple R-squared:      1,	Adjusted R-squared:    NaN
# F-statistic:   NaN on 1 and 0 DF,  p-value: NA
#
#
# $`Deinococcus-Thermus`
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Thermo)
#
# Residuals:
#      80      81      82      83      84      85
#  0.2141  0.1255 -0.1820 -1.3379 -0.5366  1.7168
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)         56.7024    40.8627   1.388    0.259
# log(AverageVolume)   1.2804     0.5928   2.160    0.120
# arrhenius_tmp       -0.3794     0.6355  -0.597    0.593
#
# Residual standard error: 1.306 on 3 degrees of freedom
# Multiple R-squared:  0.6317,	Adjusted R-squared:  0.3862
# F-statistic: 2.573 on 2 and 3 DF,  p-value: 0.2235
#
#
# $Euryarchaeota
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Thermo)
#
# Residuals:
#      86      87      88      89      90      91      92
#  0.1904 -0.6037  0.4963  1.1314  2.9890 -2.5618 -1.6417
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)         98.2823    50.4955   1.946    0.123
# log(AverageVolume)   1.3694     0.6992   1.958    0.122
# arrhenius_tmp       -1.6456     1.6098  -1.022    0.364
#
# Residual standard error: 2.243 on 4 degrees of freedom
# Multiple R-squared:  0.6273,	Adjusted R-squared:  0.4409
# F-statistic: 3.366 on 2 and 4 DF,  p-value: 0.1389
#
#
# $Firmicutes
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Thermo)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -4.190 -1.241 -0.198  1.171  5.161
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)         -7.9942    13.9220  -0.574   0.5676
# log(AverageVolume)   0.5202     0.2192   2.373   0.0203 *
# arrhenius_tmp        0.5260     0.2404   2.188   0.0319 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 1.971 on 72 degrees of freedom
# Multiple R-squared:  0.1652,	Adjusted R-squared:  0.142
# F-statistic: 7.123 on 2 and 72 DF,  p-value: 0.001504
#
#
# $Haptophyta
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Thermo)
#
# Residuals:
#      168      169      170      171      172
# -0.43064  0.23902 -0.14628  0.36460 -0.02671
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)        -16.7057    34.1328  -0.489    0.673
# log(AverageVolume)  -0.4146     0.2238  -1.853    0.205
# arrhenius_tmp       -0.2530     0.7251  -0.349    0.760
#
# Residual standard error: 0.4459 on 2 degrees of freedom
# Multiple R-squared:  0.7714,	Adjusted R-squared:  0.5429
# F-statistic: 3.375 on 2 and 2 DF,  p-value: 0.2286
#
#
# $Ochrophyta
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Thermo)
#
# Residuals:
#     173     174     175     176     177
#  0.3839 -0.2300 -0.1597  0.2318 -0.2260
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)        10.71537   11.75197   0.912   0.4581
# log(AverageVolume) -0.17505    0.09974  -1.755   0.2213
# arrhenius_tmp      -0.73299    0.23590  -3.107   0.0898 .
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.4066 on 2 degrees of freedom
# Multiple R-squared:  0.9385,	Adjusted R-squared:  0.877
# F-statistic: 15.26 on 2 and 2 DF,  p-value: 0.06152
#
#
# $Others
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Thermo)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.62894 -0.44995  0.00486  0.42347  0.99503
#
# Coefficients:
#                     Estimate Std. Error t value Pr(>|t|)
# (Intercept)        -22.37544    6.27027  -3.568  0.00181 **
# log(AverageVolume)  -0.03944    0.05766  -0.684  0.50151
# arrhenius_tmp        0.22196    0.12709   1.746  0.09534 .
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.5393 on 21 degrees of freedom
# Multiple R-squared:  0.1379,	Adjusted R-squared:  0.05576
# F-statistic: 1.679 on 2 and 21 DF,  p-value: 0.2106
#
#
# $Planctomycetes
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Thermo)
#
# Residuals:
# ALL 1 residuals are 0: no residual degrees of freedom!
#
# Coefficients: (2 not defined because of singularities)
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)          -11.42         NA      NA       NA
# log(AverageVolume)       NA         NA      NA       NA
# arrhenius_tmp            NA         NA      NA       NA
#
# Residual standard error: NaN on 0 degrees of freedom
#
#
# $Proteobacteria
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Thermo)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -2.6505 -0.4152  0.1162  0.5708  2.1902
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)         4.04986   16.26897   0.249    0.807
# log(AverageVolume) -0.04153    0.29029  -0.143    0.888
# arrhenius_tmp      -0.47259    0.35590  -1.328    0.205
#
# Residual standard error: 1.199 on 14 degrees of freedom
# Multiple R-squared:  0.1121,	Adjusted R-squared:  -0.01476
# F-statistic: 0.8836 on 2 and 14 DF,  p-value: 0.4351
#
#
# $Spirochaetes
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Thermo)
#
# Residuals:
# ALL 1 residuals are 0: no residual degrees of freedom!
#
# Coefficients: (2 not defined because of singularities)
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)          -11.89         NA      NA       NA
# log(AverageVolume)       NA         NA      NA       NA
# arrhenius_tmp            NA         NA      NA       NA
#
# Residual standard error: NaN on 0 degrees of freedom
#
#
# $Streptophyta
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Thermo)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.66546 -0.15886  0.03654  0.18030  0.36860
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)         3.15324    6.87868   0.458  0.65323
# log(AverageVolume) -0.19586    0.04501  -4.351  0.00057 ***
# arrhenius_tmp      -0.55826    0.16279  -3.429  0.00373 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.3051 on 15 degrees of freedom
# Multiple R-squared:  0.7396,	Adjusted R-squared:  0.7049
# F-statistic: 21.31 on 2 and 15 DF,  p-value: 4.138e-05
#
#
# $Synergistetes
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Thermo)
#
# Residuals:
# ALL 3 residuals are 0: no residual degrees of freedom!
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)         1001.06         NA      NA       NA
# log(AverageVolume)    15.24         NA      NA       NA
# arrhenius_tmp        -10.92         NA      NA       NA
#
# Residual standard error: NaN on 0 degrees of freedom
# Multiple R-squared:      1,	Adjusted R-squared:    NaN
# F-statistic:   NaN on 2 and 0 DF,  p-value: NA
#
#
# $Thermodesulfobacteria
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Thermo)
#
# Residuals:
#       242       243       244       245
# -0.002044 -0.003209 -0.009796  0.015050
#
# Coefficients:
#                    Estimate Std. Error t value Pr(>|t|)
# (Intercept)        45.36026    1.56986   28.89   0.0220 *
# log(AverageVolume)  0.12254    0.01010   12.14   0.0523 .
# arrhenius_tmp      -1.56030    0.04155  -37.56   0.0169 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.01836 on 1 degrees of freedom
# Multiple R-squared:  0.9993,	Adjusted R-squared:  0.9979
# F-statistic: 709.2 on 2 and 1 DF,  p-value: 0.02654
#
#
# $Thermotogae
#
# Call:
# lm(formula = log(GrowthRate) ~ log(AverageVolume) + arrhenius_tmp,
#     data = Thermo)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.77600 -0.61083 -0.06833  0.39422  2.90757
#
# Coefficients:
#                     Estimate Std. Error t value Pr(>|t|)
# (Intercept)        78.311317  31.103554   2.518   0.0305 *
# log(AverageVolume) -0.005569   0.261685  -0.021   0.9834
# arrhenius_tmp      -2.594323   1.031843  -2.514   0.0307 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 1.498 on 10 degrees of freedom
# Multiple R-squared:  0.4753,	Adjusted R-squared:  0.3704
# F-statistic: 4.529 on 2 and 10 DF,  p-value: 0.03977

# %%
#Coef_T
read.csv("C:/Users/FAN/Desktop/Results/Tables/Coef_T.csv", as.is=TRUE)
# Out:
#    ConPhylum             Kingdom       N  r.sqr     lntercept   Pr
# 1  Actinobacteria        Bacteria       3 1.0000000 5588.571155      NA
# 2  Aquificae             Bacteria      10 0.1131559    7.466141 0.94200
# 3  Bacillariophyta       Phytoplankton 43 0.3141961    2.158984 0.60033
# 4  Bacteroidetes         Bacteria       1 0.0000000  -13.117376      NA
# 5  Chloroflexi           Bacteria       2 1.0000000  160.306098      NA
# 6  Chlorophyta           Bacteria      15 0.1640909   -7.452675 0.28200
# 7  Crenarchaeota         Archaea        1 0.0000000  -13.250197      NA
# 8  Cyanophyta            Bacteria       2 1.0000000  -35.538113      NA
# 9  Deferribacteres       Bacteria       2 1.0000000 -138.720542      NA
# 10 Deinococcus-Thermus   Bacteria       6 0.6317227   56.702401 0.25900
# 11 Euryarchaeota         Archaea        7 0.6272585   98.282340 0.12300
# 12 Firmicutes            Bacteria      75 0.1651857   -7.994157 0.56760
# 13 Haptophyta            Phytoplankton  5 0.7714468  -16.705661 0.67300
# 14 Ochrophyta            Phytoplankton  5 0.9384842   10.715373 0.45810
# 15 Others                Phytoplankton 24 0.1378645  -22.375445 0.00181
# 16 Planctomycetes        Bacteria       1 0.0000000  -11.417615      NA
# 17 Proteobacteria        Bacteria      17 0.1120808    4.049856 0.80700
# 18 Spirochaetes          Bacteria       1 0.0000000  -11.886892      NA
# 19 Streptophyta          Phytoplankton 18 0.7396398    3.153237 0.65323
# 20 Synergistetes         Bacteria       3 1.0000000 1001.063134      NA
# 21 Thermodesulfobacteria Bacteria       4 0.9992955   45.360263 0.02200
# 22 Thermotogae           Bacteria      13 0.4753116   78.311317 0.03050
#    a             Pr.1     RE          Pr.2     p.value
# 1  113.511695700       NA -26.4536106       NA        NA
# 2    1.171984262 0.512000   0.9150248 0.613000 0.6568000
# 3   -0.022930459 0.509391  -0.3568890 0.000362 0.0005297
# 4             NA       NA          NA       NA        NA
# 5    4.494237833       NA          NA       NA        NA
# 6   -0.086117454 0.370000  -0.1835092 0.242000 0.3412000
# 7             NA       NA          NA       NA        NA
# 8   -0.623070729       NA          NA       NA        NA
# 9   -3.088376214       NA          NA       NA        NA
# 10   1.280449625 0.120000  -0.3794246 0.593000 0.2235000
# 11   1.369369027 0.122000  -1.6456298 0.364000 0.1389000
# 12   0.520214014 0.020300   0.5259703 0.031900 0.0015040
# 13  -0.414598939 0.205000  -0.2530276 0.760000 0.2286000
# 14  -0.175050615 0.221300  -0.7329913 0.089800 0.0615200
# 15  -0.039437317 0.501510   0.2219641 0.095340 0.2106000
# 16            NA       NA          NA       NA        NA
# 17  -0.041530627 0.888000  -0.4725868 0.205000 0.4351000
# 18            NA       NA          NA       NA        NA
# 19  -0.195855561 0.000570  -0.5582639 0.003730 0.0000414
# 20  15.239073630       NA -10.9191739       NA        NA
# 21   0.122538999 0.052300  -1.5602973 0.016900 0.0265400
# 22  -0.005568896 0.983400  -2.5943227 0.030700 0.0397700

# %%
#CoefM
read.csv("C:/Users/FAN/Desktop/Results/Tables/Coef_M.csv", as.is=TRUE)
# Out:
#    ConPhylum           Kingdom       N   r.sqr      lntercept   Pr
# 1  Actinobacteria      Bacteria        9 0.01289477 -26.5993202 0.6770
# 2  Bacillariophyta     Phytoplankton   4 0.14705284  16.3067781 0.9610
# 3  Bacteroidetes       Bacteria        6 0.32448861  45.6624645 0.4140
# 4  Balneolaeota        Phytoplankton   2 1.00000000  -4.0376764     NA
# 5  Chloroflexi         Bacteria        3 1.00000000 -65.6801547     NA
# 6  Chlorophyta         Bacteria        1 0.00000000  10.2078626     NA
# 7  Crenarchaeota       Archaea         6 0.08984658 -42.6828006 0.6520
# 8  Cyanobacteria       Bacteria       13 0.01366221  -8.0533032 0.4920
# 9  Cyanophyta          Bacteria       10 0.33013617 -28.3003542 0.2510
# 10 Deinococcus-Thermus Bacteria        1 0.00000000 -10.3250820     NA
# 11 Euryarchaeota       Archaea       139 0.03966280   0.9182511 0.8658
# 12 Firmicutes          Bacteria       63 0.03773192 -22.3854679 0.0869
# 13 Others              Phytoplankton   1 0.00000000 -12.4752601     NA
# 14 Planctomycetes      Bacteria        1 0.00000000 -11.2054408     NA
# 15 Proteobacteria      Bacteria       94 0.02141337  -9.1279648 0.3310
# 16 Spirochaetes        Bacteria        4 0.88708358  79.5031850 0.2580
#    a           Pr.1   RE          Pr.2   p.value
# 1  -0.12677551 0.8170  0.26609942 0.8510 0.9618
# 2  -0.06636945 0.7780 -0.73179822 0.9280 0.9236
# 3   0.36895497 0.5240 -1.05451268 0.3980 0.5552
# 4   0.14450684     NA          NA     NA     NA
# 5  -0.13633803     NA  1.24539834     NA     NA
# 6           NA     NA          NA     NA     NA
# 7  -0.25896480 0.7070  0.57414935 0.8480 0.8683
# 8   0.01578932 0.8260 -0.08466199 0.7710 0.9335
# 9  -0.23237514 0.1120  0.21544742 0.7220 0.2460
# 10          NA     NA          NA     NA     NA
# 11  0.24156688 0.0345 -0.07923807 0.2942 0.0638
# 12 -0.22921837 0.1332  0.07789720 0.7889 0.3154
# 13          NA     NA          NA     NA     NA
# 14          NA     NA          NA     NA     NA
# 15 -0.09558980 0.5010 -0.13413738 0.3510 0.3735
# 16  0.72051333 0.2290 -1.61459413 0.2540 0.3360

# %%
# Clear the data
rm(list=ls())

#Packages
library(ggplot2)

#Import the data
Data1 <- read.csv("C:/Users/FAN/Desktop/Data1.csv", as.is=TRUE)
Data_TM <- read.csv("C:/Users/FAN/Desktop/Data_TM.csv", as.is=TRUE)

#Clear the data
Data1<- Data1 %>% mutate(lograte = log(TCorrected_GrowthRate))
Data<- Data_TM %>% mutate(lograte = log(TCorrected_GrowthRate))
Data1 <- Data1[!is.na(Data1$E),]
Data <- Data[!is.na(Data$E),]

#Mean
mean(Data1$E)

#Parameter
k <- 8.62e-5 

#Classification
A1<-subset(Data1,Superkingdom=="Archaea")
B1<-subset(Data1,Superkingdom=="Bacteria")
P1<-subset(Data1,Superkingdom=="Phytoplankton")
unique(A1$ConPhylum)
unique(B1$ConPhylum)
unique(P1$ConPhylum)

##Plot1-G vs 1/kT
setwd("C:/Users/FAN/Desktop")

#Archaea
png(filename = "A1.jpg",width =1000, height =700)
A1$ConPhylum<-as.factor(A1$ConPhylum)
ggplot(data=A1, aes(x=log(AverageVolume),y=log(TCorrected_GrowthRate),color=ConPhylum))+
    geom_point(aes(shape=Author),size=4,alpha=0.6)+
    scale_y_continuous(name="Log(Growth rate)")+
    scale_x_continuous(name="Log(Volume)")+
    geom_smooth(method = "lm",se=F,linetype=1,size=1.5)+
    theme(plot.title = element_text(size=30),axis.title = element_text(size=28,color="black"), axis.text = element_text(size=24),panel.background = element_rect(fill = "white",colour = "black",size=1),panel.grid =element_line(color="lightgrey"),
          panel.spacing.x = unit(1, "cm"),legend.title  = element_text(size =24),legend.text = element_text(size = 20),
          strip.background.x = element_rect(fill="white"), strip.placement = "outside", strip.text.x = element_text(size = 28, color = "black"))+
    facet_wrap(. ~ ConPhylum,scales= "free")
dev.off()

#Bacteria
png(filename = "B1.jpg",width =1800, height =1500)  
B1$ConPhylum<-as.factor(B1$ConPhylum)
ggplot(data=B1, aes(x=log(AverageVolume),y=log(TCorrected_GrowthRate),color=ConPhylum))+
  geom_point(aes(shape=Author),size=4,alpha=0.6)+
  scale_y_continuous(name="Log(Growth rate)")+
  scale_x_continuous(name="Log(Volume)")+
  geom_smooth(method = "lm",se=F,linetype=1,size=1.5)+
  theme(plot.title = element_text(size=30),axis.title = element_text(size=28,color="black"), axis.text = element_text(size=24),panel.background = element_rect(fill = "white",colour = "black",size=1),panel.grid =element_line(color="lightgrey"),
        panel.spacing.x = unit(1, "cm"), panel.spacing.y = unit(2, "cm"),
        legend.title  = element_text(size =24),legend.text = element_text(size = 20),legend.position = "bottom",
        strip.background.x = element_rect(fill="white"), strip.placement = "outside", strip.text.x = element_text(size = 28, color = "black"))+
  facet_wrap(. ~ ConPhylum,ncol=3,scales= "free")
dev.off()

#Phytoplankton color = "blue", size = 1, alpha = 0.5) 
png(filename = "P1.jpg",width =1000, height =1000)  
P1$ConPhylum<-as.factor(P1$ConPhylum)
ggplot(data=P1, aes(x=log(AverageVolume),y=log(TCorrected_GrowthRate),color=ConPhylum))+
  geom_point(aes(shape=Author),size=4,alpha=0.6)+
  scale_y_continuous(name="Log(Growth rate)")+
  scale_x_continuous(name="Log(Volume)")+
  geom_smooth(method = "lm",se=F,linetype=1,size=1.5)+
  theme(plot.title = element_text(size=30),axis.title = element_text(size=28,color="black"), axis.text = element_text(size=24),panel.background = element_rect(fill = "white",colour = "black",size=1),panel.grid =element_line(color="lightgrey"),
        panel.spacing.x = unit(1, "cm"), panel.spacing.y = unit(2, "cm"),
        legend.title  = element_text(size =20),legend.text = element_text(size = 18),legend.position = "bottom",
        strip.background.x = element_rect(fill="white"), strip.placement = "outside", strip.text.x = element_text(size = 28, color = "black"))+
  facet_wrap(. ~ ConPhylum,ncol=2,scales= "free")
dev.off()

##Plot-Breakpoint
#Classification
A<-subset(Data,Superkingdom=="Archaea")
B<-subset(Data,Superkingdom=="Bacteria")
P<-subset(Data,Superkingdom=="Phytoplankton")
unique(A$ConPhylum)
unique(B$ConPhylum)
unique(P$ConPhylum)

#Archaea
png(filename = "A.jpg",width =1000, height =700) 
A$ConPhylum<-as.factor(A$ConPhylum)
ggplot(data=A, aes(x=log(AverageVolume),y=log(TCorrected_GrowthRate),color=ConPhylum))+
  geom_point(aes(shape=Author),size=4,alpha=0.6)+
  scale_y_continuous(name="Log(Growth rate)")+
  scale_x_continuous(name="Log(Volume)")+
  geom_smooth(method = "lm",se=F,linetype=1,size=1.5)+
  theme(plot.title = element_text(size=30),axis.title = element_text(size=28,color="black"), axis.text = element_text(size=24),panel.background = element_rect(fill = "white",colour = "black",size=1),panel.grid =element_line(color="lightgrey"),
        panel.spacing.x = unit(1, "cm"),legend.title  = element_text(size =24),legend.text = element_text(size = 20),
        strip.background.x = element_rect(fill="white"), strip.placement = "outside", strip.text.x = element_text(size = 28, color = "black"))+
  facet_wrap(. ~ ConPhylum,scales= "free")
dev.off()

#Bacteria
png(filename = "B.jpg",width =1800, height =1500)  
B$ConPhylum<-as.factor(B$ConPhylum)
ggplot(data=B, aes(x=log(AverageVolume),y=log(TCorrected_GrowthRate),color=ConPhylum))+
  geom_point(aes(shape=Author),size=4,alpha=0.6)+
  scale_y_continuous(name="Log(Growth rate)")+
  scale_x_continuous(name="Log(Volume)")+
  geom_smooth(method = "lm",se=F,linetype=1,size=1.5)+
  theme(plot.title = element_text(size=30),axis.title = element_text(size=28,color="black"), axis.text = element_text(size=24),panel.background = element_rect(fill = "white",colour = "black",size=1),panel.grid =element_line(color="lightgrey"),
        panel.spacing.x = unit(1, "cm"), panel.spacing.y = unit(2, "cm"),
        legend.title  = element_text(size =24),legend.text = element_text(size = 20),legend.position = "bottom",
        strip.background.x = element_rect(fill="white"), strip.placement = "outside", strip.text.x = element_text(size = 28, color = "black"))+
  facet_wrap(. ~ ConPhylum,ncol=3,scales= "free")
dev.off()

#Phytoplankton color = "blue", size = 1, alpha = 0.5) 
png(filename = "P.jpg",width =1000, height =1000)  
P$ConPhylum<-as.factor(P$ConPhylum)
ggplot(data=P, aes(x=log(AverageVolume),y=log(TCorrected_GrowthRate),color=ConPhylum))+
  geom_point(aes(shape=Author),size=4,alpha=0.6)+
  scale_y_continuous(name="Log(Growth rate)")+
  scale_x_continuous(name="Log(Volume)")+
  geom_smooth(method = "lm",se=F,linetype=1,size=1.5)+
  theme(plot.title = element_text(size=30),axis.title = element_text(size=28,color="black"), axis.text = element_text(size=24),panel.background = element_rect(fill = "white",colour = "black",size=1),panel.grid =element_line(color="lightgrey"),
        panel.spacing.x = unit(1, "cm"), panel.spacing.y = unit(2, "cm"),
        legend.title  = element_text(size =20),legend.text = element_text(size = 18),legend.position = "bottom",
        strip.background.x = element_rect(fill="white"), strip.placement = "outside", strip.text.x = element_text(size = 28, color = "black"))+
  facet_wrap(. ~ ConPhylum,ncol=2,scales= "free")
dev.off()
# Out:
# Loading required package: dplyr
# Warning message:
# "package 'dplyr' was built under R version 3.6.3"Error: package or namespace load failed for 'dplyr' in loadNamespace(i, c(lib.loc, .libPaths()), versionCheck = vI[[i]]):
#  namespace 'rlang' 0.3.4 is already loaded, but >= 0.4.10 is required
# Error in Data1 %>% mutate(lograte = log(TCorrected_GrowthRate)): 没有"%>%"这个函数
# Traceback:

# %%
# Out:
# package 'png' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\FAN\AppData\Local\Temp\RtmpWwVHQf\downloaded_packages

# %%
# Out:
# Error in readPNG("C:/Users/FAN/Desktop/Results/Figures/A.png"): unable to open C:/Users/FAN/Desktop/Results/Figures/A.png
# Traceback:
#
# 1. readPNG("C:/Users/FAN/Desktop/Results/Figures/A.png")
